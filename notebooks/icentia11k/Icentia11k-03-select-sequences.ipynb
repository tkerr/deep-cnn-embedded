# %% [markdown]
# # Icentia11k-03-select-sequences.ipynb
# Analyze the Icentia11k rhythm CSV files and create a set of CSV files that identify specific sequence examples.
# Run Icentia11k-02-find-sequences.ipynb to create rhythm CSV files, then run this notebook to create sequence CSV files.
# See https://physionet.org/content/icentia11k-continuous-ecg/1.0/
#
# ### Environment setup

# %%
import glob
import os
import re
import sys

import fileutils as fu
import icentia11k as ic

# %%
# Global objects.
seq_sec           = 30  # Sequence length in seconds
seq_length        = ic.num_samples(seq_sec)  # Sequence length in samples
seq_leader_sec    = 5   # Sequence leader length in seconds - used for filtering
seq_leader_length = ic.num_samples(seq_leader_sec) # Sequence leader length in samples

rhythms_file_pat = re.compile(ic.RHYTHMS_FILE_RE)

# %% [markdown]
# #### Functions

# %%
# Parse a line from the rhythms CSV file into zero or more examples matching the desired lengths.
# Returns a list of (pid, sid, rtype, start, length) tuples of the desired length.
def parse_rhythm(rhythm_list, seq_leader_length, seq_length):
    example_list = []
    (pid, sid, rtype, start, length) = rhythm_list
    i_start = int(start)
    i_length = int(length)
    i_remain = i_length
    total_length = seq_leader_length + seq_length
    while (i_remain >= seq_length):
        
        if (i_start >= seq_leader_length):
            # Case 1: There is sufficient leader before the start of the rhythm sequence.
            #print('Case 1')
            this_start = i_start - seq_leader_length
            i_remain -= seq_length
            i_start += seq_length
            example = (pid, sid, rtype, this_start, total_length)
            example_list.append(example)
            #ic.pprint(example)
            
        elif ((i_start + i_length) >= total_length):
            # Case 2: There is insufficient leader before the start of the rhythm sequence, but
            # there is enough rhythm sequence for the leader to encroach into the start of it.
            #print('Case 2')
            this_start = 0
            i_remain -= (total_length - i_start)
            i_start = total_length
            example = (pid, sid, rtype, this_start, total_length)
            example_list.append(example)
            #ic.pprint(example)
            
        else:
            # Not enough ECG to work with.
            #print('Case 3')
            i_remain = 0
        
    return example_list

# %%
# Add a list of rhythm sequences to a CSV file.
# Data is appended to the end of the file.
def add_sequences_to_file(sequences_list, sequences_file):
    with fu.open_file(sequences_file, 'a') as fd:
        for seq_tuple in sequences_list:
            (pid, sid, rtype, start, length) = seq_tuple
            rec = '{},{},{},{},{}\n'.format(pid, sid, rtype, start, length)
            fd.write(rec)
    fd.close()

# %% [markdown]
# ### Run this cell to create the sequences CSV files
# Each time this cell is run, it appends to existing files.

# %%
for sd in ic.SUBDIRS:
    local_dir = os.path.join(ic.LOCAL_DATA_PATH, sd)
    rhythm_file_list = sorted(glob.glob(os.path.join(local_dir, 'rhythms*.csv')))

    for rhythm_file in rhythm_file_list:
        print(rhythm_file)
    
        pid_range = rhythms_file_pat.search(rhythm_file).group(1)
        rfd = fu.open_file(rhythm_file)
        for line in rfd:
    
            # Split the line in the rhythms file into a list of individual parts.
            rhythm_list = line.strip().split(',')
    
            sequences_list = parse_rhythm(rhythm_list, seq_leader_length, seq_length)
            sequences_file = 'sequences_{}_{}.csv'.format(pid_range, rhythm_list[2].upper())
            sequences_path = os.path.join(local_dir, sequences_file)
    
            add_sequences_to_file(sequences_list, sequences_path)
    
        fu.close_file(rfd)
# Out:
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00000_p00099.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00100_p00199.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00200_p00299.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00300_p00399.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00400_p00499.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00500_p00599.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00600_p00699.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00700_p00799.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00800_p00899.csv
# D:\dev\jupyter\Icentia11k\data\p00\rhythms_p00900_p00999.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01000_p01099.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01100_p01199.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01200_p01299.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01300_p01399.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01400_p01499.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01500_p01599.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01600_p01699.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01700_p01799.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01800_p01899.csv
# D:\dev\jupyter\Icentia11k\data\p01\rhythms_p01900_p01999.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02000_p02099.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02100_p02199.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02200_p02299.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02300_p02399.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02400_p02499.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02500_p02599.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02600_p02699.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02700_p02799.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02800_p02899.csv
# D:\dev\jupyter\Icentia11k\data\p02\rhythms_p02900_p02999.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03000_p03099.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03100_p03199.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03200_p03299.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03300_p03399.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03400_p03499.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03500_p03599.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03600_p03699.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03700_p03799.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03800_p03899.csv
# D:\dev\jupyter\Icentia11k\data\p03\rhythms_p03900_p03999.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04000_p04099.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04100_p04199.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04200_p04299.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04300_p04399.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04400_p04499.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04500_p04599.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04600_p04699.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04700_p04799.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04800_p04899.csv
# D:\dev\jupyter\Icentia11k\data\p04\rhythms_p04900_p04999.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05000_p05099.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05100_p05199.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05200_p05299.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05300_p05399.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05400_p05499.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05500_p05599.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05600_p05699.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05700_p05799.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05800_p05899.csv
# D:\dev\jupyter\Icentia11k\data\p05\rhythms_p05900_p05999.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06000_p06099.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06100_p06199.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06200_p06299.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06300_p06399.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06400_p06499.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06500_p06599.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06600_p06699.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06700_p06799.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06800_p06899.csv
# D:\dev\jupyter\Icentia11k\data\p06\rhythms_p06900_p06999.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07000_p07099.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07100_p07199.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07200_p07299.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07300_p07399.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07400_p07499.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07500_p07599.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07600_p07699.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07700_p07799.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07800_p07899.csv
# D:\dev\jupyter\Icentia11k\data\p07\rhythms_p07900_p07999.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08000_p08099.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08100_p08199.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08200_p08299.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08300_p08399.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08400_p08499.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08500_p08599.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08600_p08699.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08700_p08799.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08800_p08899.csv
# D:\dev\jupyter\Icentia11k\data\p08\rhythms_p08900_p08999.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09000_p09099.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09100_p09199.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09200_p09299.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09300_p09399.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09400_p09499.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09500_p09599.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09600_p09699.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09700_p09799.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09800_p09899.csv
# D:\dev\jupyter\Icentia11k\data\p09\rhythms_p09900_p09999.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10000_p10099.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10100_p10199.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10200_p10299.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10300_p10399.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10400_p10499.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10500_p10599.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10600_p10699.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10700_p10799.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10800_p10899.csv
# D:\dev\jupyter\Icentia11k\data\p10\rhythms_p10900_p10999.csv

# %% [markdown]
# ### Check the files created above

# %%
afl_file_pat = re.compile('sequences_p\d{5}_p\d{5}_AFL\.csv')
afib_file_pat = re.compile('sequences_p\d{5}_p\d{5}_AFIB\.csv')
n_file_pat = re.compile('sequences_p\d{5}_p\d{5}_N\.csv')
q_file_pat = re.compile('sequences_p\d{5}_p\d{5}_Q\.csv')

afib_count = 0
afl_count = 0
n_count = 0
q_count = 0

for (dirpath, dirs, files) in os.walk(ic.LOCAL_DATA_PATH):
    for file in files:
        
        if afl_file_pat.match(file):
            sequences_file = os.path.join(dirpath, file)
            with fu.open_file(sequences_file) as sfp:
                for line in sfp:
                    if (len(line.strip()) > 0):
                        afl_count += 1
            fu.close_file(sfp)
            
        elif afib_file_pat.match(file):
            sequences_file = os.path.join(dirpath, file)
            with fu.open_file(sequences_file) as sfp:
                for line in sfp:
                    if (len(line.strip()) > 0):
                        afib_count += 1
            fu.close_file(sfp)
        
        elif n_file_pat.match(file):
            sequences_file = os.path.join(dirpath, file)
            with fu.open_file(sequences_file) as sfp:
                for line in sfp:
                    if (len(line.strip()) > 0):
                        n_count += 1
            fu.close_file(sfp)
            
        elif q_file_pat.match(file):
            sequences_file = os.path.join(dirpath, file)
            with fu.open_file(sequences_file) as sfp:
                for line in sfp:
                    if (len(line.strip()) > 0):
                        q_count += 1
            fu.close_file(sfp)
print('AFL: {}, AFIB: {}, N: {}, Q: {}'.format(afl_count, afib_count, n_count, q_count))
# Out:
# AFL: 825775, AFIB: 2424476, N: 47187038, Q: 8208588
